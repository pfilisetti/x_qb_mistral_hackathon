# %%
import pandas as pd

gift_dataset_final = pd.read_csv('data_gifts.csv', sep=';', encoding="latin1")

# %%
gift_dataset_final.sample(10)
# Out:
#            name_of_the_product    main_category        sub_category  ratings  \
# 106      Sennheiser Momentum 3            Audio          Headphones      4.6
# 145       Salomon Speedcross 5            Shoes      Athletic Shoes      4.5
# 417         Luxury Bath Towels    Wedding Gifts          Home Decor      4.9
# 8                  The Odyssey            Books  Classic Literature      4.7
# 202             The Dark Tower            Books             Fantasy      4.8
# 87          Cuisinart Griddler  Home Appliances  Kitchen Appliances      4.5
# 152       Lego Star Wars AT-AT             Toys       Building Sets      4.8
# 120              Canon EOS M50          Cameras          Mirrorless      4.6
# 390     Escape Room: The Heist    Group Outings        Escape Rooms      4.9
# 394  Hiking Tour: Grand Canyon    Group Outings        Hiking Tours      4.8
#
#      no_of_ratings  discounted_price  actual_price
# 106           2100            349.99        399.99
# ...
