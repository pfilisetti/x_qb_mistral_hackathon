# %%
import pandas as pd

gift_dataset_final = pd.read_csv('data_gifts.csv', sep=';', encoding="latin1")

# %%
gift_dataset_final.sample(10)
# Out:
#                                name_of_the_product        main_category  \
# 217                                      Realme GT               Phones
# 273  Black+Decker 12-Cup Programmable Coffee Maker      Home Appliances
# 94                                  Fitbit Versa 3  Wearable Technology
# 137                            Asics Gel-Nimbus 23                Shoes
# 103                        Bose QuietComfort 35 II                Audio
# 281                           Apple Watch Series 6  Wearable Technology
# 480      Personalized Wedding Album: Leather Bound        Wedding Gifts
# 349             Lego Architecture Trafalgar Square        Building Sets
# 323                               Nike Air Max 270       Athletic Shoes
# 292                           Bose QuietComfort 45                Audio
#
#            sub_category  ratings  no_of_ratings  discounted_price  \
# 217         Smartphones      4.7          14400            449.99
# 273  Kitchen Appliances      4.7          14600             49.99
# 94         Smartwatches      4.6           1800            229.99
# 137      Athletic Shoes      4.7           2650            139.99
# 103          Headphones      4.6           2500            299.99
# 281        Smartwatches      4.8          14000            399.99
# 480  Personalized Gifts      4.7          14300            179.99
# 349        Architecture      4.7          12600             79.99
# 323       Running Shoes      4.8          13000            129.99
# 292          Headphones      4.8          14000            279.99
#
#      actual_price
# 217        649.99
# 273         69.99
# 94         279.99
# 137        169.99
# 103        349.99
# 281        499.99
# 480        229.99
# 349         99.99
# 323        159.99
# 292        329.99

# %%
sub_category = gift_dataset_final["sub_category"].unique()

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\thiba\anaconda3\lib\site-packages (4.46.3)
# Requirement already satisfied: filelock in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (2.32.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\thiba\anaconda3\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\thiba\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\thiba\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\thiba\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thiba\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thiba\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thiba\anaconda3\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thiba\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import BertTokenizer, BertModel
import torch

# %%
# Charger le modèle et le tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Fonction pour obtenir les embeddings
def obtenir_embeddings(texte):
    inputs = tokenizer(texte, return_tensors='pt', padding=True, truncation=True)
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings

# Calculer les embeddings pour chaque idée de cadeau
embeddings_cadeaux = [obtenir_embeddings(idea) for idea in sub_category]

# Convertir les embeddings en liste de tensors
embeddings_cadeaux = torch.stack(embeddings_cadeaux).squeeze()

# Afficher les embeddings (seulement les 5 premiers éléments pour chaque embedding)
for i, embedding in enumerate(embeddings_cadeaux):
    print(f"Embedding pour l'idée de cadeau {i+1}: {embedding[:5]}")
# Out:
# Embedding pour l'idée de cadeau 1: tensor([ 0.2902,  0.2751, -0.4873, -0.3871,  0.1275], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 2: tensor([ 0.3013,  0.0496, -0.2024,  0.1459,  0.2160], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 3: tensor([ 0.1041, -0.3579, -0.1523,  0.1184,  0.1730], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 4: tensor([ 0.2074, -0.3238, -0.1434,  0.1510, -0.1093], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 5: tensor([ 0.2480,  0.1472, -0.0465,  0.0514,  0.0927], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 6: tensor([ 0.2346,  0.5764, -0.3144,  0.0999,  0.3174], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 7: tensor([ 0.3376, -0.4088, -0.0149,  0.0122,  0.3175], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 8: tensor([0.5394, 0.0499, 0.0326, 0.1633, 0.5266], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau 9: tensor([ 0.5355, -0.2999,  0.1422,  0.2664,  0.5556], grad_fn=<SliceBackward0>)
# Embedding pour l'idée de cadeau


# %%
from sklearn.metrics.pairwise import cosine_similarity

# Fonction pour trouver les trois éléments les plus proches
def trouver_elements_proches(element_entree):
    # Calculer l'embedding pour l'élément d'entrée
    embedding_entree = obtenir_embeddings(element_entree)

    # Calculer la similarité cosinus entre l'embedding de l'élément d'entrée et les embeddings de la liste
    similarities = cosine_similarity(embedding_entree.detach().numpy(), embeddings_cadeaux.detach().numpy())

    # Trouver les indices des trois éléments les plus similaires
    top_indices = similarities.argsort()[0][-3:]

    # Renvoyer les trois éléments les plus similaires
    top_cadeaux = [sub_category[i] for i in top_indices]
    return top_cadeaux

# Exemple d'utilisation
element_entree = ["Smartphones"]
elements_proches = trouver_elements_proches(element_entree)
print(f"Les trois éléments les plus proches de '{element_entree}' sont : {elements_proches}")
# Out:
# Les trois éléments les plus proches de '['Smartphones']' sont : ['Smartwatches', 'Android Tablets', 'Smartphones']

# %%
budget = 0

label = ["Classic Litterature"]

def pre_filtering(label, customer_budget):
    customer_needs = trouver_elements_proches(label)
    selection = gift_dataset_final[gift_dataset_final["sub_category"].isin(customer_needs)]
    selection_price = selection[selection["discounted_price"] < customer_budget]

    return selection_price


customer_budget = 700

test = pre_filtering(label, customer_budget)
test
# Out:
#                     name_of_the_product      main_category  \
# 0                      The Great Gatsby              Books
# 1                 To Kill a Mockingbird              Books
# 2                                  1984              Books
# 3                   Pride and Prejudice              Books
# 4                             Moby Dick              Books
# 5                             Jane Eyre              Books
# 6                     Wuthering Heights              Books
# 7                The Catcher in the Rye              Books
# 8                           The Odyssey              Books
# 9                    The Scarlet Letter              Books
# 10   The Adventures of Huckleberry Finn              Books
# 11                  The Grapes of Wrath              Books
# 12                   The Sun Also Rises              Books
# 13              The Old Man and the Sea              Books
# 14               The Sound and the Fury              Books
# 388      Wine Tasting Tour: Napa Valley      Group Outings
# 401                    High-End Perfume     Birthday Gifts
# 432                High-End Perfume Set  Anniversary Gifts
# 449         Wine Tasting Tour: Bordeaux      Group Outings
# 462                    High-End Cologne     Birthday Gifts
# 493      High-End Perfume Set: Designer  Anniversary Gifts
#
#            sub_category  ratings  no_of_ratings  discounted_price  \
# 0    Classic Literature      4.5           1200              8.99
# 1    Classic Literature      4.8           1500              6.99
# 2    Classic Literature      4.6           1450              7.99
# 3    Classic Literature      4.7           1300              5.99
# 4    Classic Literature      4.4           1100              6.99
# 5    Classic Literature      4.6           1250              7.99
# 6    Classic Literature      4.5           1200              6.99
# 7    Classic Literature      4.3           1000              7.99
# 8    Classic Literature      4.7           1350              8.99
# 9    Classic Literature      4.6           1200              7.99
# 10   Classic Literature      4.5           1150              6.99
# 11   Classic Literature      4.7           1300              7.99
# 12   Classic Literature      4.6           1250              8.99
# 13   Classic Literature      4.8           1400              6.99
# 14   Classic Literature      4.5           1100              7.99
# 388        Wine Tasting      4.7          13800            149.99
# 401          Fragrances      4.6          13700             79.99
# 432          Fragrances      4.6          13700            149.99
# 449        Wine Tasting      4.7          13800            129.99
# 462          Fragrances      4.6          13700             69.99
# 493          Fragrances      4.6          13700            179.99
#
#      actual_price
# 0           12.99
# 1            9.99
# 2           10.99
# 3            8.99
# 4            9.99
# 5           10.99
# 6            9.99
# 7           10.99
# 8           12.99
# 9           10.99
# 10           9.99
# 11          10.99
# 12          12.99
# 13           9.99
# 14          10.99
# 388        199.99
# 401         99.99
# 432        199.99
# 449        179.99
# 462         89.99
# 493        229.99
